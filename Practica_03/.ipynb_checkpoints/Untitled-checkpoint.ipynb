# %% [markdown]
# # Practica 03 : Analisis de datos Exploratorio con Python y Jupiter Notebook

# %% [markdown]
# **Programa de Estudio:** Ingenieria en Desarrollo y Gestion de Software\
# **Asignatura:** Extraccion deConocimientos de Base de Datos\
# **Docente:** M.T.I. Marco Antonio Ramirez \
# **Periodo:** Mayo - Agosto 2026

# %% [markdown]
# ### Unida2: Preparación de Datos

# %% [markdown]
# **Nombre del Estudiante:** Brisa Nallely Garcia Gregorio\
# **Matricula:** 230362\
# **Grado y Grupo:** 9° IDGS\

# %% [markdown]
# El estudiante practicara como realizar un analisis exploratorio de datos utilizando el lenguaje de programacion de Python y librerias comunes para la carga, manipulacion analisis y visualizacion previa de un conjunto de datos (Dataset)
# - Pandas
# - Numby
# - Seanborn
# - os
# - Matplotlib

# %% [markdown]
# 1.- Importar las librerias necesarias para realizar el EDA\
# Comenzamos por importar la libreria que nos permitirá manipular los datos del dataset extraidos de una fuente de datos (Datasource)

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# 2.- Creamos un DataFrame leyendo el archivo delimitado por comas (CSV)

# %%
pokemons=pd.read_csv('./Pokemon.csv')

# %% [markdown]
# 3.-Imprimimos el resultado de la lectura\
# Esteb comando permite en una tabla las columnas y las filas del dataframe, siempre de manera estámdar nos mostrara los primeros 5 registros ultimos

# %% [markdown]
# pokemons

# %% [markdown]
# 4.- Obtener una muestra aleatoria de registros del dataframe usando el metodo simple como parametro de entrada podemos definir un entorno que determina el tamaño de la muestra

# %%
pokemons.sample(5)
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78     130
# 68    63                       Abra  Psychic     NaN    310   25      20
# 500  450                  Hippowdon   Ground     NaN    525  108     112
# 263  244                      Entei     Fire     NaN    580  115     115
# 481  433                  Chingling  Psychic     NaN    285   45      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7        111      130       85    100           1      False
# 68        15      105       55     90           1      False
# 500      118       68       72     47           4      False
# 263       85       90       75    100           2       True
# 481       50       65       50     45           4      False

# %% [markdown]
# **Ejercicio 1:** Obtener una muestra de 50 pokemones

# %%
pokemons.sample(50)
# Out:
#        #                       Name    Type 1   Type 2  Total   HP  Attack  \
# 520  469                    Yanmega       Bug   Flying    515   86      76
# 240  222                    Corsola     Water     Rock    380   55      55
# 366  334        AltariaMega Altaria    Dragon    Fairy    590   75     110
# 668  607                    Litwick     Ghost     Fire    275   50      30
# 360  329                    Vibrava    Ground   Dragon    340   50      70
# 44    39                 Jigglypuff    Normal    Fairy    270  115      45
# 533  479            RotomWash Rotom  Electric    Water    520   50      65
# 407  372                    Shelgon    Dragon      NaN    420   65      95
# 545  487       GiratinaOrigin Forme     Ghost   Dragon    680  150     120
# 137  127          PinsirMega Pinsir       Bug   Flying    600   65     155
# 353  323                   Camerupt      Fire   Ground    460   70     100
# ...

# %% [markdown]
# 5.- Obtener una muestra de rangos definidos usando **.iloc**

# %%
pokemons_100_to_200 = pokemons.iloc[100:200]
pokemons_100_to_200
# Out:
#        #                   Name    Type 1  Type 2  Total   HP  Attack  \
# 100   93                Haunter     Ghost  Poison    405   45      50
# 101   94                 Gengar     Ghost  Poison    500   60      65
# 102   94      GengarMega Gengar     Ghost  Poison    600   60      65
# 103   95                   Onix      Rock  Ground    385   35      45
# 104   96                Drowzee   Psychic     NaN    328   60      48
# ..   ...                    ...       ...     ...    ...  ...     ...
# 195  181               Ampharos  Electric     NaN    510   90      75
# 196  181  AmpharosMega Ampharos  Electric  Dragon    610   90      95
# 197  182              Bellossom     Grass     NaN    490   75      80
# 198  183                 Marill     Water   Fairy    250   70      20
# 199  184              Azumarill     Water   Fairy    420  100      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 100       45      115       55     95           1      False
# ...

# %% [markdown]
# 6.- Como saber las columnas o atributos tiene el dataframe

# %%
pokemons.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# Campo Descripción #: El ID o número de identificación del Pokémon\
# **Name:** El nombre del Pokémon.\
# **Type 1:** Se refiere a las propiedades elementales (tipos) asociadas tanto al Pokémon como a sus movimientos\
# **Type 2:** Los Pokémon pueden tener hasta dos tipos (Pokémon de tipo dual), los movimientos solo pueden tener uno.\
# **Total:** Representa la suma de todos los stats, lo que te da una idea de qué tan "pesado" o fuerte es el Pokémon.\
# **HP:** (Puntos de Salud) Es qué tanto aguante tiene un Pokémon antes de que lo dejen fuera de combate (se desmaye).\
# **Attack:** La fuerza de los ataques físicos del Pokémon.\
# **Defense:** Qué tanto aguanta el Pokémon contra los ataques fisicos del rival.\
# **Sp. Atk:** Ataque Especial; el poder de los movimientos especiales del Pokémon.\
# **Sp. Def:** Defensa Especial; qué tan resistente es el Pokémon ante los ataques especiales.\
# **Speed:** Velocidad, el Pokémon que tenga más velocidad es el que ataca primero.\
# **Generation:** Se refiere a la generación de la serie de juegos a la que pertenece.\
# **Legendary:** Indica si el Pokémon es Legendario o no (son bichos muy raros y poderosos). Es un valor booleano (si/no).

# %% [markdown]
# 7.- Explorar la composición y ausencia de datos (METADATA) con **.info**\
# La libreta de pandas, incliye un método que nos permite evaluar el tipo de datos y su composición y ausencia

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# 8.- Limpieza de Datos\
# Dependimiento del objetivo del análisis algunas columnas o registros no serán necesarias en nuestro dataframe en este caso omitiremos los datos vacios, por lo que eliminaremos la columna "Type 2" y renombraremos la columna "Type 1" por "Type"

# %%
del pokemons['Type 2']
pokemons.rename(columns ={'Type 1': "Type"})
# Out:
#        #                   Name     Type  Total  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur    Grass    318  45      49       49       65
# 1      2                Ivysaur    Grass    405  60      62       63       80
# 2      3               Venusaur    Grass    525  80      82       83      100
# 3      3  VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4      4             Charmander     Fire    309  39      52       43       60
# ..   ...                    ...      ...    ...  ..     ...      ...      ...
# 800  719                Diancie     Rock    600  50     100      150      100
# 801  719    DiancieMega Diancie     Rock    700  50     160      110      160
# 802  720    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 803  720     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 804  721              Volcanion     Fire    600  80     110      120      130
#
# ...

# %% [markdown]
# **Ejercicio 02:** Consulta la METADATA de la actualización y compara los cambios con la anterior\
# ¿Qué cambios vez? redacta tu respuesta

# %% [markdown]
# 9.- Visualizacion de los rpimeros datos usando el método **.head**

# %%
pokemons.head()
# Out:
#    #                   Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass    318  45      49       49       65
# 1  2                Ivysaur  Grass    405  60      62       63       80
# 2  3               Venusaur  Grass    525  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass    625  80     100      123      122
# 4  4             Charmander   Fire    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# **Ejercicio 03:** Muestra los ultimos 10 registros de dataframe

# %% [markdown]
# 10.- Estadistica basica del dataframe Pandas permite un reporte de estadistica basica de tendencia sobre daqtos cuantitativos usando el comando **describe**

# %%
pokemons.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# 11.- Para calcular el total de datos no diplicados (unicos)\
# Usaremos **len()** como funciona para calcular la longitud del frame y **.unique**\
# **NOTA** nO CONSIDERAR 10 como un atributo de llave primaria, si no el total de columnas como un solo elemento u objeto.\
# Obteniendo los valores unicos por columna en estecaso en la columna "Name"

# %%
len(pokemons.Name.unique())
# Out:
# 800

# %% [markdown]
# Obteniendo el total de objetos (conjunto de atributos, estrictamente iguales) unicos.

# %%
total_unicos = len(pokemons.drop_duplicates())
total_unicos
# Out:
# 800

# %% [markdown]
# **Ejercicio 04:** Obtener el total de IDs únicos en el dataset

# %%
len(pokemons['#'].unique())
# Out:
# 721

# %% [markdown]
# **Ejercicio 05** Obtener el total de tipos unicos de Pokemones

# %%
len(pokemons['Type 1'].unique())
# Out:
# 18

# %% [markdown]
# 12.- Contabilización de Datos por Atributo Pandas nos permite agrupar los datos por atributo y contabilizar lor totales usando\
# **.value_counts()** ¿Cuantos pokemones hay por generación?

# %%
pokemons.Generation.value_counts()
# Out:
# Generation
# 1    168
# 5    165
# 3    160
# 4    121
# 2    109
# 6     82
# Name: count, dtype: int64

# %% [markdown]
# 13.- En este apartado usaremos **countplot** el cual se utiliza para contabilizar el numero de pokemones agrupados por generación

# %%
Se hizo una correccion al codigo original:sns.countplot(x='Generation',data=pokemons,palette='nipy_spectral')
plt.title('Number of pokemons grouped by generation')\
ya que aparecia un error de verción

# %%
sns.countplot(
    x='Generation',
    hue='Generation',
    data=pokemons,
    palette='nipy_spectral',
    legend=False
)

plt.title('Número de Pokémon agrupados por generación')
plt.show()

# %% [markdown]
# ¿Cuántos Pokémon hay de cada tipo?
# Recordemos que el dataset la columna de 'type2', por lo que en este analisi consideramos...

# %% [markdown]
# 14.- value_counts() cuenta la frecuencia de cada tipo de Pokémon y muestra los resultados ordenados de mayor a menor cantidad.

# %%
pokemons['Type 1'].value_counts()
# Out:
# Type 1
# Water       114
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         46
# Electric     45
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# 15.- **countplot()** crea una gráfica de barras que muestra la cantidad de Pokémon que pertenecen a cada tipo principal (Type 1).\
# Cada barra representa un tipo y su altura indica cuántos Pokémon hay de ese tipo en el conjunto de datos.

# %%
plt.figure(figsize=(15,5))

sns.countplot(
    x='Type 1',
    hue='Type 1',
    data=pokemons,
    palette='twilight',
    legend=False
)

plt.title('Cantidad de Pokémon por tipo')
plt.show()
